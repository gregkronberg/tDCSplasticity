# %%
import neurons
import functions
import matplotlib.pyplot as plt
import stims
import run_control
import numpy as np
import param
import analyze_exp
reload(functions)
reload(neurons.neuron_reduce.reducing_methods)
reload(neurons.neuron_reduce.subtree_reductor_func)
reload(param)
reload(neurons)
reload(functions)
reload(run_control)
reload(stims)
reload(analyze_exp)
# Out:
# <module 'analyze_exp' from 'analyze_exp.pyc'>

# %%
exp = run_control.exp_full_neuron_polarization_dose_response()

# %%
# exp.run()
# Out:
# loading cell geometry: CellMigliore2005
# loading cell range mechanisms
# inserting synapses
# creating morpho object
# setting up recording vectors
# simulation finished
# trial_id:2020-03-27-12-41-17-753000-82579, duration:14.9489998817
# saving data
# setting up recording vectors
# simulation finished
# trial_id:2020-03-27-12-41-44-773000-26995, duration:14.7339999676
# saving data
# setting up recording vectors
# simulation finished
# trial_id:2020-03-27-12-42-11-398000-05523, duration:14.9340000153
# saving data
# setting up recording vectors
# simulation finished
# trial_id:2020-03-27-12-42-37-863000-46163, duration:15.0789999962
# saving data
# setting up recording vectors
# simulation finished
# trial_id:2020-03-27-12-43-04-448000-15763, duration:13.9099998474
# saving data
# setting up recording vectors
# simulation finished
# trial_id:2020-03-27-12-43-30-35000-63891, duration:15.1370000839
# saving data
# setting up recording vectors
# simulation finished
# ...

# %%
exp.vtrace_df[['location','polarization']]
# Out:
#                    location  polarization
# 0              (soma, 0, 0)     -0.526526
# 1              (axon, 0, 0)     -0.861359
# 2              (axon, 0, 1)     -1.334702
# 3              (axon, 0, 2)     -0.581603
# 4              (axon, 0, 3)      0.171535
# 5              (axon, 0, 4)     -0.153728
# 6              (axon, 0, 5)     -0.884305
# 7              (axon, 0, 6)     -1.523654
# 8       (apical_tuft, 0, 0)      0.852088
# 9       (apical_tuft, 1, 0)      0.622832
# 10      (apical_tuft, 1, 1)      1.443113
# 11      (apical_tuft, 1, 2)      2.275657
# 12      (apical_tuft, 2, 0)      0.094267
# 13      (apical_tuft, 3, 0)      0.438811
# 14      (apical_tuft, 3, 1)      1.083116
# 15      (apical_tuft, 3, 2)      1.802841
# 16      (apical_tuft, 4, 0)      0.311337
# 17      (apical_tuft, 4, 1)      0.802086
# 18      (apical_tuft, 4, 2)      1.281488
# 19      (apical_tuft, 5, 0)      0.148000
# 20      (apical_tuft, 6, 0)      0.675799
# ...

# %%
df_funcs = [functions.DfFuncs()._get_polarization]
df_func_kwargs= [{}]
exp.generate_group_variable_vtrace(df_funcs=df_funcs, df_func_kwargs=df_func_kwargs)
# Out:
# files []
# no group data found
# search_string data
# total data files: 3
# new data files: 3
# updating group data structure
# iter files: 3
# processing file 0
# new file found: 2020-03-27-11-31-58-538000-59219
# processing file 1
# new file found: 2020-03-27-11-32-24-764000-87283
# processing file 2
# new file found: 2020-03-27-11-32-57-245000-76179
# saving updated group df
# file size 9338352
# total size 9338352
# splitting group df
