# %%
import neurons
import functions
import matplotlib.pyplot as plt
import stims
import run_control
import numpy as np
import param
import analyze_exp
reload(functions)
reload(neurons.neuron_reduce.reducing_methods)
reload(neurons.neuron_reduce.subtree_reductor_func)
reload(param)
reload(neurons)
reload(functions)
reload(run_control)
reload(stims)
reload(analyze_exp)
# Out:
# <module 'analyze_exp' from 'analyze_exp.pyc'>

# %%
exp = run_control.exp_reduced_neuron_polarization()

# %%
exp.run()
# Out:
# loading cell geometry: CellMigliore2005Reduced
# loading cell range mechanisms
# inserting synapses
# creating morpho object
# WARNING The template 'model' is already defined... not loading.
# inserting synapses
# creating morpho object
# setting up recording vectors
# simulation finished
# trial_id:2020-04-04-09-55-07-88000-01587, duration:0.415999889374
# saving data
# setting up recording vectors
# simulation finished
# trial_id:2020-04-04-09-55-07-961000-04595, duration:0.393000125885
# saving data
# setting up recording vectors
# simulation finished
# trial_id:2020-04-04-09-55-08-732000-21907, duration:0.388000011444
# saving data
# setting up recording vectors
# simulation finished
# trial_id:2020-04-04-09-55-09-506000-09875, duration:0.371000051498
# saving data
# setting up recording vectors
# simulation finished
# trial_id:2020-04-04-09-55-10-242000-21011, duration:0.407999992371
# saving data
# setting up recording vectors
# simulation finished
# trial_id:2020-04-04-09-55-11-28000-89619, duration:0.389999866486
# saving data
# setting up recording vectors
# simulation finished
# trial_id:2020-04-04-09-55-11-788000-47891, duration:0.362999916077
# saving data
# setting up recording vectors
# simulation finished
# trial_id:2020-04-04-09-55-12-494000-04115, duration:0.371999979019
# saving data
# setting up recording vectors
# simulation finished
# trial_id:2020-04-04-09-55-13-290000-24403, duration:0.368000030518
# saving data
# setting up recording vectors
# simulation finished
# trial_id:2020-04-04-09-55-14-32000-15219, duration:0.385999917984
# saving data
# setting up recording vectors
# simulation finished
# trial_id:2020-04-04-09-55-14-806000-70483, duration:0.362999916077
# saving data
# files []
# no group data found
# search_string data
# total data files: 11
# new data files: 11
# updating group data structure
# iter files: 11
# processing file 0
# new file found: 2020-04-04-09-55-07-88000-01587
# processing file 1
# new file found: 2020-04-04-09-55-07-961000-04595
# processing file 2
# new file found: 2020-04-04-09-55-08-732000-21907
# processing file 3
# new file found: 2020-04-04-09-55-09-506000-09875
# processing file 4
# new file found: 2020-04-04-09-55-10-242000-21011
# processing file 5
# new file found: 2020-04-04-09-55-11-28000-89619
# processing file 6
# new file found: 2020-04-04-09-55-11-788000-47891
# processing file 7
# new file found: 2020-04-04-09-55-12-494000-04115
# processing file 8
# new file found: 2020-04-04-09-55-13-290000-24403
# processing file 9
# new file found: 2020-04-04-09-55-14-32000-15219
# processing file 10
# new file found: 2020-04-04-09-55-14-806000-70483
# saving updated group df
# file size 1100922
# total size 1100922
# splitting group df
# applying df function: _get_polarization
# processing all rows
# saving updated group df
# file size 1097754
# total size 1097754
# splitting group df

# %%
df = functions._set_index(exp.vtrace_df, ['field','tree_key'])
# Out:
#           polarization seg_dist
# tree_key
# soma          4.102006   3.7455
# apic          1.874596  82.2503
# apic          1.222077  246.751
# apic          0.642587  411.251
# apic          0.107712  575.752
# apic         -0.420150  740.253
# apic         -0.992118  904.753
# apic         -1.671643  1069.25
# apic         -2.539821  1233.75
# apic         -3.699182  1398.25
# apic         -5.295423  1562.76
# apic         -7.551389  1727.26
# dend          7.085045  80.1605
# dend          8.921295    225.5
# dend         11.183707  370.839
# dend          6.220135  57.7482
# dend          7.590424  158.263
# dend          9.207101  258.777

# %%
seg_dist_dend = -1.*df.loc[(20, 'dend')].seg_dist.values
seg_dist_apic = df.loc[(20, 'apic')].seg_dist.values
polarization_dend = df.loc[(20, 'dend')].polarization.values
polarization_apic = df.loc[(20, 'apic')].polarization.values
plt.figure()
plt.plot(seg_dist_apic, polarization_apic)
plt.plot(seg_dist_dend, polarization_dend)
# Out:
# F:\Anaconda2\lib\site-packages\ipykernel_launcher.py:1: PerformanceWarning: indexing past lexsort depth may impact performance.
#   """Entry point for launching an IPython kernel.
# F:\Anaconda2\lib\site-packages\ipykernel_launcher.py:2: PerformanceWarning: indexing past lexsort depth may impact performance.
#
# F:\Anaconda2\lib\site-packages\ipykernel_launcher.py:3: PerformanceWarning: indexing past lexsort depth may impact performance.
#   This is separate from the ipykernel package so we can avoid doing imports until
# F:\Anaconda2\lib\site-packages\ipykernel_launcher.py:4: PerformanceWarning: indexing past lexsort depth may impact performance.
#   after removing the cwd from sys.path.

# %%
df.loc[(20,'apic')]
# Out:
# F:\Anaconda2\lib\site-packages\ipykernel_launcher.py:1: PerformanceWarning: indexing past lexsort depth may impact performance.
#   """Entry point for launching an IPython kernel.
#                      location sec_num seg_num    seg_loc  \
# field tree_key
# 20    apic       (apic, 0, 0)       0       0  0.0833333
#       apic       (apic, 0, 1)       0       1   0.166667
#       apic       (apic, 0, 2)       0       2       0.25
#       apic       (apic, 0, 3)       0       3   0.333333
#       apic       (apic, 0, 4)       0       4   0.416667
#       apic       (apic, 0, 5)       0       5        0.5
#       apic       (apic, 0, 6)       0       6   0.583333
#       apic       (apic, 0, 7)       0       7   0.666667
#       apic       (apic, 0, 8)       0       8       0.75
#       apic       (apic, 0, 9)       0       9   0.833333
#       apic      (apic, 0, 10)       0      10   0.916667
#
#                                                            data_t seg_dist  \
# field tree_key
# 20    apic      [0.0, 0.025, 0.05, 0.075, 0.09999999999999999,...  82.2503
#       apic      [0.0, 0.025, 0.05, 0.075, 0.09999999999999999,...  246.751
#       apic      [0.0, 0.025, 0.05, 0.075, 0.09999999999999999,...  411.251
#       apic      [0.0, 0.025, 0.05, 0.075, 0.09999999999999999,...  575.752
#       apic      [0.0, 0.025, 0.05, 0.075, 0.09999999999999999,...  740.253
#       apic      [0.0, 0.025, 0.05, 0.075, 0.09999999999999999,...  904.753
#       apic      [0.0, 0.025, 0.05, 0.075, 0.09999999999999999,...  1069.25
#       apic      [0.0, 0.025, 0.05, 0.075, 0.09999999999999999,...  1233.75
#       apic      [0.0, 0.025, 0.05, 0.075, 0.09999999999999999,...  1398.25
#       apic      [0.0, 0.025, 0.05, 0.075, 0.09999999999999999,...  1562.76
#       apic      [0.0, 0.025, 0.05, 0.075, 0.09999999999999999,...  1727.26
#
#                                                            morpho n_paths  \
# field tree_key
# 20    apic      (1, apic_0_0, 0.0, 172.72560847889292, 0.0, 6....       1
#       apic      (2, apic_0_1, 0.0, 337.22618761929596, 0.0, 6....       1
#       apic      (3, apic_0_2, 0.0, 501.72676675969905, 0.0, 6....       1
#       apic      (4, apic_0_3, 0.0, 666.2273459001021, 0.0, 6.1...       1
#       apic      (5, apic_0_4, 0.0, 830.727925040505, 0.0, 6.19...       1
#       apic      (6, apic_0_5, 0.0, 995.228515625, 0.0, 6.19822...       1
#       apic      (7, apic_0_6, 0.0, 1159.7290833213112, 0.0, 6....       1
#       apic      (8, apic_0_7, 0.0, 1324.2296624617145, 0.0, 6....       1
#       apic      (9, apic_0_8, 0.0, 1488.7302416021175, 0.0, 6....       1
#       apic      (10, apic_0_9, 0.0, 1653.2308207425206, 0.0, 6...       1
#       apic      (11, apic_0_10, 0.0, 1817.7313998829238, 0.0, ...       1
#
#                path paths  ... AXONM Vrest field_on  \
# field tree_key             ...
# 20    apic      NaN    []  ...   100   -65        0
#       apic      NaN    []  ...   100   -65        0
#       apic      NaN    []  ...   100   -65        0
#       apic      NaN    []  ...   100   -65        0
#       apic      NaN    []  ...   100   -65        0
#       apic      NaN    []  ...   100   -65        0
#       apic      NaN    []  ...   100   -65        0
#       apic      NaN    []  ...   100   -65        0
#       apic      NaN    []  ...   100   -65        0
#       apic      NaN    []  ...   100   -65        0
#       apic      NaN    []  ...   100   -65        0
#
#                                 field_names fig_folder full_path diam1_basal  \
# field tree_key
# 20    apic      [cathodal, control, anodal]                False         1.9
#       apic      [cathodal, control, anodal]                False         1.9
#       apic      [cathodal, control, anodal]                False         1.9
#       apic      [cathodal, control, anodal]                False         1.9
#       apic      [cathodal, control, anodal]                False         1.9
#       apic      [cathodal, control, anodal]                False         1.9
#       apic      [cathodal, control, anodal]                False         1.9
#       apic      [cathodal, control, anodal]                False         1.9
#       apic      [cathodal, control, anodal]                False         1.9
#       apic      [cathodal, control, anodal]                False         1.9
#       apic      [cathodal, control, anodal]                False         1.9
#
#                mechanism_v                                             data_v  \
# field tree_key
# 20    apic               v  [-71.4, -71.3941475757056, -71.38867477587782,...
#       apic               v  [-71.4, -71.39783422621889, -71.39558224678214...
#       apic               v  [-71.4, -71.40016617359427, -71.40017123261525...
#       apic               v  [-71.4, -71.40061220268251, -71.40118715034207...
#       apic               v  [-71.4, -71.4007863893476, -71.40156190758601,...
#       apic               v  [-71.4, -71.40089993420025, -71.40179227219829...
#       apic               v  [-71.4, -71.40097560403568, -71.40194150220638...
#       apic               v  [-71.4, -71.40098281570573, -71.40196111318745...
#       apic               v  [-71.4, -71.40098880679744, -71.40197320669675...
#       apic               v  [-71.4, -71.4009893168037, -71.40197494978102,...
#       apic               v  [-71.4, -71.4009939625931, -71.4019835813142, ...
#
#                polarization
# field tree_key
# 20    apic         1.874596
#       apic         1.222077
#       apic         0.642587
#       apic         0.107712
#       apic        -0.420150
#       apic        -0.992118
#       apic        -1.671643
#       apic        -2.539821
#       apic        -3.699182
#       apic        -5.295423
#       apic        -7.551389
#
# [11 rows x 132 columns]
