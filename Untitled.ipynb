# %%
import neurons
import functions
import matplotlib.pyplot as plt
import stims
import run_control
import numpy as np
import param
import analyze_exp
reload(param)
reload(run_control.neuron)
reload(functions)
reload(neurons.neuron_reduce.reducing_methods)
reload(neurons.neuron_reduce.subtree_reductor_func)
reload(neurons)
reload(functions)
reload(stims)
reload(analyze_exp)
reload(run_control)
# Out:
# <module 'run_control' from 'run_control.py'>

# %%
exp = run_control.exp_reduced_neuron_tbs_distal()

# %%
exp.run()
# Out:
# loading cell geometry: CellMigliore2005Reduced
# loading cell range mechanisms
# inserting synapses
# creating morpho object
# WARNING The template 'model' is already defined... not loading.
# inserting synapses
# creating morpho object
# setting up recording vectors
# simulation finished
# converting input_times [ 10.  20.  30.  40. 210. 220. 230. 240. 410. 420. 430. 440.]
# trial_id:2020-04-14-11-35-56-600000-24339, duration:3.02200007439
# saving data
# setting up recording vectors
# simulation finished
# converting input_times [ 10.  20.  30.  40. 210. 220. 230. 240. 410. 420. 430. 440.]
# trial_id:2020-04-14-11-35-59-878000-00851, duration:2.6859998703
# saving data
# setting up recording vectors
# simulation finished
# converting input_times [ 10.  20.  30.  40. 210. 220. 230. 240. 410. 420. 430. 440.]
# trial_id:2020-04-14-11-36-02-826000-10963, duration:2.65300011635
# saving data

# %%
# exp._load_group_variable(variable='vtrace_df')
# v_df = functions._set_index(exp.vtrace_df, ['path_1_w_mean'])
# exp.vtrace_df = v_df.loc[(.0058, .0059, .006, .0061, .0062),:]
# exp._load_group_variable(variable='w_clopath_df')
exp.generate_group_variables()
# clopath_param = param.ParamClopath().kronberg_2020_reduced()
# exp.generate_group_variable_w_clopath(rerun=False, clopath_param=clopath_param,input_times_key='data_input_times')
# Out:
# files []
# no group data found
# search_string data
# total data files: 3
# new data files: 3
# updating group data structure
# iter files: 3
# processing file 0
# new file found: 2020-04-14-11-35-56-600000-24339
# processing file 1
# new file found: 2020-04-14-11-35-59-878000-00851
# processing file 2
# new file found: 2020-04-14-11-36-02-826000-10963
# saving updated group df
# file size 125946
# total size 125946
# splitting group df
# chunk  0 , size:  (2, 169)
# chunk  1 , size:  (2, 169)
# chunk  2 , size:  (2, 169)
# chunk  3 , size:  (2, 169)
# chunk  4 , size:  (2, 169)
# chunk  5 , size:  (2, 169)
# chunk  6 , size:  (2, 169)
# chunk  7 , size:  (2, 169)
# chunk  8 , size:  (1, 169)
# chunk  9 , size:  (1, 169)
# saving updated group df
# file size 125946
# total size 125946
# splitting group df
# chunk  0 , size:  (2, 169)
# chunk  1 , size:  (2, 169)
# chunk  2 , size:  (2, 169)
# chunk  3 , size:  (2, 169)
# chunk  4 , size:  (2, 169)
# chunk  5 , size:  (2, 169)
# chunk  6 , size:  (2, 169)
# chunk  7 , size:  (2, 169)
# chunk  8 , size:  (1, 169)
# chunk  9 , size:  (1, 169)
# generating w_clopath_df
# files []
# no group data found
# applying df function: _get_w_clopath
# clopath_params {'tetap': -61, 'tau_m': 20, 'upper_bound': None, 'A_p': 0.0004, 'lower_bound': 0.0, 'LTD_delay': 1, 'delay': 0, 'adapt_t': 40000, 'tau_x': 8, 'u_ref': 9, 'E_L': -70.6, 'tetam': -70, 'tau_p': 3, 'A_m0': 0.001}
# timer: 2.39600014687
# saving updated group df
# file size 2948922
# total size 2948922
# splitting group df
# chunk  0 , size:  (2, 173)
# chunk  1 , size:  (2, 173)
# chunk  2 , size:  (2, 173)
# chunk  3 , size:  (2, 173)
# chunk  4 , size:  (2, 173)
# chunk  5 , size:  (2, 173)
# chunk  6 , size:  (2, 173)
# chunk  7 , size:  (2, 173)
# chunk  8 , size:  (1, 173)
# chunk  9 , size:  (1, 173)

# %%
plt.figure()
plt.plot(functions._2array(exp.vtrace_df.data_v).T)
# Out:
# [<matplotlib.lines.Line2D at 0x1aa04390>,
#  <matplotlib.lines.Line2D at 0x1aa04438>,
#  <matplotlib.lines.Line2D at 0x1aa044e0>,
#  <matplotlib.lines.Line2D at 0x1aa04588>,
#  <matplotlib.lines.Line2D at 0x1aa04630>,
#  <matplotlib.lines.Line2D at 0x1aa046d8>,
#  <matplotlib.lines.Line2D at 0x1aa04780>,
#  <matplotlib.lines.Line2D at 0x1aa04828>,
#  <matplotlib.lines.Line2D at 0x1aa048d0>,
#  <matplotlib.lines.Line2D at 0x1aa04978>,
#  <matplotlib.lines.Line2D at 0x1aa04a20>,
#  <matplotlib.lines.Line2D at 0x1aa04ac8>,
#  <matplotlib.lines.Line2D at 0x1aa04b70>,
#  <matplotlib.lines.Line2D at 0x1aa04c18>,
#  <matplotlib.lines.Line2D at 0x1aa04cc0>,
#  <matplotlib.lines.Line2D at 0x1aa04d68>,
#  <matplotlib.lines.Line2D at 0x1aa04e10>,
#  <matplotlib.lines.Line2D at 0x1aa04eb8>]
