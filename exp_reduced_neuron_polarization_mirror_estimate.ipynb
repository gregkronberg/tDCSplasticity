# %%
import neurons
import functions
import matplotlib.pyplot as plt
import stims
import run_control
import numpy as np
import param
import analyze_exp
reload(functions)
reload(neurons.neuron_reduce.reducing_methods)
reload(neurons.neuron_reduce.subtree_reductor_func)
reload(param)
reload(neurons)
reload(functions)
reload(run_control)
reload(stims)
reload(analyze_exp)
# Out:
# <module 'analyze_exp' from 'analyze_exp.pyc'>

# %%
exp = run_control.exp_reduced_neuron_polarization_mirror_estimate()

# %%
exp.run()
# Out:
# loading cell geometry: CellMigliore2005Reduced
# loading cell range mechanisms
# inserting synapses
# creating morpho object
# WARNING The template 'model' is already defined... not loading.
# inserting synapses
# creating morpho object
# loading cell geometry: CellMigliore2005
# loading cell range mechanisms
# inserting synapses
# creating morpho object
# ...

# %%
plt.figure()
plt.plot(functions._2array(exp.data.data_v).T)

# %%
# exp.polarization_map[('dend',0,2)]

# %%
# e_map = _get_mirror_estimate_from_polarization(polarization_map=exp.polarization_map, reduced_cell=exp.cell, map_method='linear_fit')

# %%
# exp.vtrace_df[['location','polarization_original_cell_mean']]

# %%
# functions._set_index(exp.vtrace_df_original,['tree_key'])[['field','polarization']].loc['apical_tuft']

# %%
# functions._set_index(exp.vtrace_df,['tree_key'])[['field','polarization']]

# %%
import analyze_exp as ae
reload(ae.figsetup)
reload(ae)
# Out:
# <module 'analyze_exp' from 'analyze_exp.pyc'>

# %%
# a = ae.analysis_exp_full_neuron_polarization_dose_response()

# %%
# a.shapeplot(width_scale=5)

# %%
np.sum(list(zip(*exp.e_map)[1]))
exp.e_map
exp.polarization_map
# exp.cell.geo['dend'][0].diam
# Out:
# {('apic', 0, 0): [-0.5790935063860729],
#  ('apic', 0, 1): [-0.34266209070770515,
#   -0.23544053241299423,
#   -0.19981462383960036,
#   -0.6152316125178032,
#   -1.2942612033210281,
#   -1.3869921272824257,
#   -1.115693028799825,
#   -0.2156052178490171,
#   -0.13483417487505278,
#   -0.06654560826602562,
#   -0.07424535055945114,
#   -0.14937822860470362,
#   -0.5841118526524411,
#   -0.31080279214953066,
#   0.1390866454033386,
#   -0.008885779009176531,
#   -0.6751124444451619,
#   -0.15354266802307848,
#   -0.26525838966291815,
#   -0.6743722143247481,
#   -0.09709260926919683,
#   -0.09738104054295604,
#   -0.6356746881093329,
#   -0.10225295746330687,
#   -0.1959166471334015,
#   0.05027670864835443,
#   -0.3997249374352805,
#   -0.36726948365598844,
#   -0.34594169289202625,
#   0.0023320982279528835,
#   -0.36273609945567387,
#   -0.04410545117798392,
#   -0.7014317832297934,
#   0.0726081950963362,
#   -0.9171536839723018,
#   -1.5122694260938374,
# ...

# %%
a2 = ae.analysis_exp_reduced_neuron_polarization_mirror_estimate(generate_figures=True)
# Out:
# files ['Data/exp_reduced_neuron_polarization_mirror_estimate\\vtrace_df_0.pkl', 'Data/exp_reduced_neuron_polarization_mirror_estimate\\vtrace_df_1.pkl', 'Data/exp_reduced_neuron_polarization_mirror_estimate\\vtrace_df_2.pkl', 'Data/exp_reduced_neuron_polarization_mirror_estimate\\vtrace_df_3.pkl', 'Data/exp_reduced_neuron_polarization_mirror_estimate\\vtrace_df_4.pkl', 'Data/exp_reduced_neuron_polarization_mirror_estimate\\vtrace_df_5.pkl', 'Data/exp_reduced_neuron_polarization_mirror_estimate\\vtrace_df_6.pkl', 'Data/exp_reduced_neuron_polarization_mirror_estimate\\vtrace_df_7.pkl', 'Data/exp_reduced_neuron_polarization_mirror_estimate\\vtrace_df_8.pkl', 'Data/exp_reduced_neuron_polarization_mirror_estimate\\vtrace_df_9.pkl']
# 10 variable files found
# group data loaded Data/exp_reduced_neuron_polarization_mirror_estimate\vtrace_df_0.pkl
# group data loaded Data/exp_reduced_neuron_polarization_mirror_estimate\vtrace_df_1.pkl
# ...

# %%
a2.vtrace_df[['location','polarization','polarization_original_cell_mean', 'extracellular_voltage']]
# a2.vtrace_df[['seg_dist','extracellular_voltage']]
# plt.figure()
# plt.plot(a2.vtrace_df.seg_dist, a2.vtrace_df.extracellular_voltage,'.')
# Out:
#          location  polarization polarization_original_cell_mean  \
# 0    (soma, 0, 0)     -0.418030                       -0.526526
# 1    (apic, 0, 0)      1.908004                        0.692347
# 2    (apic, 0, 1)      1.520330                         0.46003
# 3    (apic, 0, 2)      1.221672                        0.905378
# 4    (apic, 0, 3)      1.006938                          1.1946
# 5    (apic, 0, 4)      0.875053                               0
# 6    (apic, 0, 5)      0.820993                        0.547886
# 7    (apic, 0, 6)      0.843665                               0
# 8    (apic, 0, 7)      0.947673                         2.18263
# 9    (apic, 0, 8)      1.142895                          2.8129
# 10   (apic, 0, 9)      1.448207                         1.27898
# 11  (apic, 0, 10)      1.893334                         3.20687
# 12   (dend, 0, 0)     -0.945858                        -1.44316
# 13   (dend, 0, 1)     -3.583431                         -1.4574
# ...

# %%
exp.polarization_map
# Out:
# {('apic', 0, 0): [-0.5790935063860729],
#  ('apic', 0, 1): [-0.34266209070770515,
#   -0.23544053241299423,
#   -0.19981462383960036,
#   -0.6152316125178032,
#   -1.2942612033210281,
#   -1.3869921272824257,
#   -1.115693028799825,
#   -0.2156052178490171,
#   -0.13483417487505278,
#   -0.06654560826602562,
#   -0.07424535055945114,
#   -0.14937822860470362,
#   -0.5841118526524411,
#   -0.31080279214953066,
#   0.1390866454033386,
#   -0.008885779009176531,
#   -0.6751124444451619,
#   -0.15354266802307848,
#   -0.26525838966291815,
#   -0.6743722143247481,
#   -0.09709260926919683,
#   -0.09738104054295604,
#   -0.6356746881093329,
#   -0.10225295746330687,
#   -0.1959166471334015,
#   0.05027670864835443,
#   -0.3997249374352805,
#   -0.36726948365598844,
#   -0.34594169289202625,
#   0.0023320982279528835,
#   -0.36273609945567387,
#   -0.04410545117798392,
#   -0.7014317832297934,
#   0.0726081950963362,
#   -0.9171536839723018,
#   -1.5122694260938374,
# ...

# %%
# figdf = f.polarization_dose_response()

# %%
# figdf.fig_ylim_all

# %%
7./1.8
# Out:
# 3.888888888888889

# %%
2.5/.3
# Out:
# 8.333333333333334
