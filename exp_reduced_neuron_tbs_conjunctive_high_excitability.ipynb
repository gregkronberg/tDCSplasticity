# %%
import neurons
import functions
import matplotlib.pyplot as plt
import stims
import run_control
import numpy as np
import param
import analyze_exp
reload(param)
reload(run_control.neuron)
reload(functions)
reload(neurons.neuron_reduce.reducing_methods)
reload(neurons.neuron_reduce.subtree_reductor_func)
reload(neurons)
reload(functions)
reload(stims)
reload(analyze_exp)
reload(run_control)
# Out:
# <module 'run_control' from 'run_control.pyc'>

# %%
exp = run_control.exp_reduced_neuron_tbs_conjunctive_high_excitability()

# %%
exp.run()
# Out:
# loading cell geometry: CellMigliore2005Reduced
# loading cell range mechanisms
# inserting synapses
# creating morpho object
# loading template 'model'
# loading default reduced model
# inserting synapses
# creating morpho object
# w_mean 1 0.003
# w_mean 2 0.0014
# setting up recording vectors
# simulation finished
# converting input_times [ 20.  30.  40.  50.  60. 220. 230. 240. 250. 260. 420. 430. 440. 450.
#  460. 620. 630. 640. 650. 660. 820. 830. 840. 850. 860.]
# trial_id:2020-04-29-13-04-37-618000-07699, duration:6.6890001297
# saving data
# setting up recording vectors
# simulation finished
# converting input_times [ 20.  30.  40.  50.  60. 220. 230. 240. 250. 260. 420. 430. 440. 450.
#  460. 620. 630. 640. 650. 660. 820. 830. 840. 850. 860.]
# trial_id:2020-04-29-13-04-44-726000-93267, duration:6.43099999428
# saving data
# setting up recording vectors
# simulation finished
# converting input_times [ 20.  30.  40.  50.  60. 220. 230. 240. 250. 260. 420. 430. 440. 450.
#  460. 620. 630. 640. 650. 660. 820. 830. 840. 850. 860.]
# trial_id:2020-04-29-13-04-51-551000-16979, duration:6.45899987221
# saving data

# %%
exp.generate_group_variables()
# Out:
# files []
# no group data found
# search_string data
# total data files: 3
# new data files: 3
# updating group data structure
# iter files: 3
# processing file 0
# new file found: 2020-04-29-13-04-37-618000-07699
# processing file 1
# new file found: 2020-04-29-13-04-44-726000-93267
# processing file 2
# new file found: 2020-04-29-13-04-51-551000-16979
# saving updated group df
# file size 287172
# total size 287172
# splitting group df
# chunk  0 , size:  (4, 187)
# chunk  1 , size:  (4, 187)
# chunk  2 , size:  (4, 187)
# chunk  3 , size:  (4, 187)
# chunk  4 , size:  (4, 187)
# chunk  5 , size:  (4, 187)
# chunk  6 , size:  (3, 187)
# chunk  7 , size:  (3, 187)
# chunk  8 , size:  (3, 187)
# chunk  9 , size:  (3, 187)
# saving updated group df
# file size 287172
# total size 287172
# splitting group df
# chunk  0 , size:  (4, 187)
# chunk  1 , size:  (4, 187)
# chunk  2 , size:  (4, 187)
# chunk  3 , size:  (4, 187)
# chunk  4 , size:  (4, 187)
# chunk  5 , size:  (4, 187)
# chunk  6 , size:  (3, 187)
# chunk  7 , size:  (3, 187)
# chunk  8 , size:  (3, 187)
# chunk  9 , size:  (3, 187)
# generating w_clopath_df
# files []
# no group data found
# applying df function: _get_w_clopath
# clopath_params {'tetap': -61, 'tau_m': 20, 'upper_bound': None, 'A_p': 0.0004, 'lower_bound': 0.0, 'LTD_delay': 1, 'delay': 0, 'adapt_t': 40000, 'tau_x': 8, 'u_ref': 9, 'E_L': -70.6, 'tetam': -70, 'tau_p': 3, 'A_m0': 0.001}
# timer: 5.48599982262
# saving updated group df
# file size 11808324
# total size 11808324
# splitting group df
# chunk  0 , size:  (4, 191)
# chunk  1 , size:  (4, 191)
# chunk  2 , size:  (4, 191)
# chunk  3 , size:  (4, 191)
# chunk  4 , size:  (4, 191)
# chunk  5 , size:  (4, 191)
# chunk  6 , size:  (3, 191)
# chunk  7 , size:  (3, 191)
# chunk  8 , size:  (3, 191)
# chunk  9 , size:  (3, 191)

# %%
v_df = functions._set_index(exp.vtrace_df, ['field', 'tree_key', 'seg_num'])
w_df = functions._set_index(exp.w_clopath_df, ['field', 'tree_key', 'seg_num'])

# %%
# plt.figure()
# plt.plot(functions._2array(v_df.loc[(-5, 'apic', (0,1,2,3,4,5))].data_mgBlock).T, 'b')
# plt.plot(functions._2array(v_df.loc[(0,'apic',(0,1,2,3,4,5))].data_mgBlock).T, 'k')
# plt.plot(functions._2array(v_df.loc[(5,'apic',(0,1,2,3,4,5))].data_mgBlock).T, 'r')
# # plt.xlim([200*40, 320*40])
# plt.ylim([0, 0.2])

plt.figure()
plt.plot(functions._2array(v_df.loc[(-5, 'apic', (0,1,2,3,4,5))].data_v).T, 'b')
plt.plot(functions._2array(v_df.loc[(0,'apic',(0,1,2,3,4,5))].data_v).T, 'k')
plt.plot(functions._2array(v_df.loc[(5,'apic',(0,1,2,3,4,5))].data_v).T, 'r')
# plt.xlim([200*40, 320*40])

plt.figure()

plt.plot(functions._2array(v_df.loc[(0,'apic',(6,7,8,9,10))].data_v).T, 'k')
# plt.plot(functions._2array(v_df.loc[(5,'apic',(6,7,8,9,10))].data_v).T, 'r')
# plt.plot(functions._2array(v_df.loc[(-5, 'apic',(6,7,8,9,10))].data_v).T, 'b')
# plt.xlim([200*40, 320*40])

# plt.figure()
# plt.plot(functions._2array(v_df.loc[(-5, 'apic')].data_i).T, 'b')
# plt.plot(functions._2array(v_df.loc[(0,'apic')].data_i).T, 'k')
# plt.plot(functions._2array(v_df.loc[(5,'apic')].data_i).T, 'r')
# plt.xlim([200*40, 320*40])

plt.figure()
# plt.plot(functions._2array(v_df.loc[(-5, 'soma')].data_v).T, 'b')
plt.plot(functions._2array(v_df.loc[(0,'soma')].data_v).T, 'k')
# plt.plot(functions._2array(v_df.loc[(5,'soma')].data_v).T, 'r')
# plt.xlim([200*40, 320*40])
plt.ylim([-72, -20])
# Out:
# F:\Anaconda2\lib\site-packages\ipykernel_launcher.py:29: PerformanceWarning: indexing past lexsort depth may impact performance.
# (-72, -20)
