# %%
import neurons
import functions
import matplotlib.pyplot as plt
import stims
import run_control
import numpy as np
import param
import analyze_exp
reload(functions)
reload(neurons.neuron_reduce.reducing_methods)
reload(neurons.neuron_reduce.subtree_reductor_func)
reload(param)
reload(neurons)
reload(functions)
reload(run_control)
reload(stims)
reload(analyze_exp)
# Out:
# <module 'analyze_exp' from 'analyze_exp.pyc'>

# %%
exp = run_control.exp_reduced_neuron_polarization_mirror_estimate_test()

# %%
exp.run()
# Out:
# loading cell geometry: CellMigliore2005Reduced
# loading cell range mechanisms
# inserting synapses
# creating morpho object
# WARNING The template 'model' is already defined... not loading.
# inserting synapses
# creating morpho object
# loading cell geometry: CellMigliore2005
# loading cell range mechanisms
# inserting synapses
# creating morpho object
# files ['Data/exp_reduced_neuron_polarization\\vtrace_df_0.pkl', 'Data/exp_reduced_neuron_polarization\\vtrace_df_1.pkl', 'Data/exp_reduced_neuron_polarization\\vtrace_df_2.pkl', 'Data/exp_reduced_neuron_polarization\\vtrace_df_3.pkl', 'Data/exp_reduced_neuron_polarization\\vtrace_df_4.pkl', 'Data/exp_reduced_neuron_polarization\\vtrace_df_5.pkl', 'Data/exp_reduced_neuron_polarization\\vtrace_df_6.pkl', 'Data/exp_reduced_neuron_polarization\\vtrace_df_7.pkl', 'Data/exp_reduced_neuron_polarization\\vtrace_df_8.pkl', 'Data/exp_reduced_neuron_polarization\\vtrace_df_9.pkl']
# 10 variable files found
# group data loaded Data/exp_reduced_neuron_polarization\vtrace_df_0.pkl
# group data loaded Data/exp_reduced_neuron_polarization\vtrace_df_1.pkl
# group data loaded Data/exp_reduced_neuron_polarization\vtrace_df_2.pkl
# group data loaded Data/exp_reduced_neuron_polarization\vtrace_df_3.pkl
# group data loaded Data/exp_reduced_neuron_polarization\vtrace_df_4.pkl
# group data loaded Data/exp_reduced_neuron_polarization\vtrace_df_5.pkl
# group data loaded Data/exp_reduced_neuron_polarization\vtrace_df_6.pkl
# group data loaded Data/exp_reduced_neuron_polarization\vtrace_df_7.pkl
# group data loaded Data/exp_reduced_neuron_polarization\vtrace_df_8.pkl
# group data loaded Data/exp_reduced_neuron_polarization\vtrace_df_9.pkl

# %%
exp.vtrace_df_original.loc[0]
# Out:
#               tree_key sec_num seg_num    seg_loc  \
# location
# (soma, 0, 0)      soma       0       0        0.5
# (apic, 0, 0)      apic       0       0  0.0833333
# (apic, 0, 1)      apic       0       1   0.166667
# (apic, 0, 2)      apic       0       2       0.25
# (apic, 0, 3)      apic       0       3   0.333333
# (apic, 0, 4)      apic       0       4   0.416667
# (apic, 0, 5)      apic       0       5        0.5
# (apic, 0, 6)      apic       0       6   0.583333
# (apic, 0, 7)      apic       0       7   0.666667
# (apic, 0, 8)      apic       0       8       0.75
# (apic, 0, 9)      apic       0       9   0.833333
# (apic, 0, 10)     apic       0      10   0.916667
# (dend, 0, 0)      dend       0       0       0.25
# (dend, 0, 1)      dend       0       1        0.5
# (dend, 0, 2)      dend       0       2       0.75
# (dend, 1, 0)      dend       1       0       0.25
# (dend, 1, 1)      dend       1       1        0.5
# (dend, 1, 2)      dend       1       2       0.75
#
#                                                           data_t seg_dist  \
# location
# (soma, 0, 0)   [0.0, 0.025, 0.05, 0.075, 0.09999999999999999,...    5e-10
# (apic, 0, 0)   [0.0, 0.025, 0.05, 0.075, 0.09999999999999999,...  82.1015
# (apic, 0, 1)   [0.0, 0.025, 0.05, 0.075, 0.09999999999999999,...  246.304
# (apic, 0, 2)   [0.0, 0.025, 0.05, 0.075, 0.09999999999999999,...  410.507
# (apic, 0, 3)   [0.0, 0.025, 0.05, 0.075, 0.09999999999999999,...   574.71
# (apic, 0, 4)   [0.0, 0.025, 0.05, 0.075, 0.09999999999999999,...  738.913
# (apic, 0, 5)   [0.0, 0.025, 0.05, 0.075, 0.09999999999999999,...  903.116
# (apic, 0, 6)   [0.0, 0.025, 0.05, 0.075, 0.09999999999999999,...  1067.32
# (apic, 0, 7)   [0.0, 0.025, 0.05, 0.075, 0.09999999999999999,...  1231.52
# (apic, 0, 8)   [0.0, 0.025, 0.05, 0.075, 0.09999999999999999,...  1395.73
# (apic, 0, 9)   [0.0, 0.025, 0.05, 0.075, 0.09999999999999999,...  1559.93
# (apic, 0, 10)  [0.0, 0.025, 0.05, 0.075, 0.09999999999999999,...  1724.13
# (dend, 0, 0)   [0.0, 0.025, 0.05, 0.075, 0.09999999999999999,...  72.5002
# (dend, 0, 1)   [0.0, 0.025, 0.05, 0.075, 0.09999999999999999,...    217.5
# (dend, 0, 2)   [0.0, 0.025, 0.05, 0.075, 0.09999999999999999,...  362.501
# (dend, 1, 0)   [0.0, 0.025, 0.05, 0.075, 0.09999999999999999,...  50.3081
# (dend, 1, 1)   [0.0, 0.025, 0.05, 0.075, 0.09999999999999999,...  150.924
# (dend, 1, 2)   [0.0, 0.025, 0.05, 0.075, 0.09999999999999999,...  251.541
#
#                                                           morpho n_paths path  \
# location
# (soma, 0, 0)   (0, soma_0_0, 0.0, -3.74549984932, 0.0, 7.4910...       0  NaN
# (apic, 0, 0)   (1, apic_0_0, 0.0, 78.35598130659623, 0.0, 6.1...       0  NaN
# (apic, 0, 1)   (2, apic_0_1, 0.0, 242.55894123424181, 0.0, 6....       0  NaN
# (apic, 0, 2)   (3, apic_0_2, 0.0, 406.7619011618874, 0.0, 6.1...       0  NaN
# (apic, 0, 3)   (4, apic_0_3, 0.0, 570.964861089533, 0.0, 6.19...       0  NaN
# (apic, 0, 4)   (5, apic_0_4, 0.0, 735.1678210171785, 0.0, 6.1...       0  NaN
# (apic, 0, 5)   (6, apic_0_5, 0.0, 899.370788574, 0.0, 6.19085...       0  NaN
# (apic, 0, 6)   (7, apic_0_6, 0.0, 1063.57374087247, 0.0, 6.19...       0  NaN
# (apic, 0, 7)   (8, apic_0_7, 0.0, 1227.7767008001156, 0.0, 6....       0  NaN
# (apic, 0, 8)   (9, apic_0_8, 0.0, 1391.9796607277613, 0.0, 6....       0  NaN
# (apic, 0, 9)   (10, apic_0_9, 0.0, 1556.182620655407, 0.0, 6....       0  NaN
# (apic, 0, 10)  (11, apic_0_10, 0.0, 1720.3855805830524, 0.0, ...       0  NaN
# (dend, 0, 0)   (12, dend_0_0, 0.0, -76.24564870198567, 0.0, 6...       0  NaN
# (dend, 0, 1)   (13, dend_0_1, 0.0, -221.2459487915039, 0.0, 6...       0  NaN
# (dend, 0, 2)   (14, dend_0_2, 0.0, -366.2462488810221, 0.0, 6...       0  NaN
# (dend, 1, 0)   (15, dend_1_0, 0.0, -54.05361684163411, 0.0, 4...       0  NaN
# (dend, 1, 1)   (16, dend_1_1, 0.0, -154.66986084, 0.0, 4.3421...       0  NaN
# (dend, 1, 2)   (17, dend_1_2, 0.0, -255.28608957926429, 0.0, ...       0  NaN
#
#               paths  ... clopath_tetap AXONM Vrest field_on  \
# location             ...
# (soma, 0, 0)     []  ...           -65   100   -65        0
# (apic, 0, 0)     []  ...           -65   100   -65        0
# (apic, 0, 1)     []  ...           -65   100   -65        0
# (apic, 0, 2)     []  ...           -65   100   -65        0
# (apic, 0, 3)     []  ...           -65   100   -65        0
# (apic, 0, 4)     []  ...           -65   100   -65        0
# (apic, 0, 5)     []  ...           -65   100   -65        0
# (apic, 0, 6)     []  ...           -65   100   -65        0
# (apic, 0, 7)     []  ...           -65   100   -65        0
# (apic, 0, 8)     []  ...           -65   100   -65        0
# (apic, 0, 9)     []  ...           -65   100   -65        0
# (apic, 0, 10)    []  ...           -65   100   -65        0
# (dend, 0, 0)     []  ...           -65   100   -65        0
# (dend, 0, 1)     []  ...           -65   100   -65        0
# (dend, 0, 2)     []  ...           -65   100   -65        0
# (dend, 1, 0)     []  ...           -65   100   -65        0
# (dend, 1, 1)     []  ...           -65   100   -65        0
# (dend, 1, 2)     []  ...           -65   100   -65        0
#
#                                field_names fig_folder full_path diam1_basal  \
# location
# (soma, 0, 0)   [cathodal, control, anodal]                False         1.9
# (apic, 0, 0)   [cathodal, control, anodal]                False         1.9
# (apic, 0, 1)   [cathodal, control, anodal]                False         1.9
# (apic, 0, 2)   [cathodal, control, anodal]                False         1.9
# (apic, 0, 3)   [cathodal, control, anodal]                False         1.9
# (apic, 0, 4)   [cathodal, control, anodal]                False         1.9
# (apic, 0, 5)   [cathodal, control, anodal]                False         1.9
# (apic, 0, 6)   [cathodal, control, anodal]                False         1.9
# (apic, 0, 7)   [cathodal, control, anodal]                False         1.9
# (apic, 0, 8)   [cathodal, control, anodal]                False         1.9
# (apic, 0, 9)   [cathodal, control, anodal]                False         1.9
# (apic, 0, 10)  [cathodal, control, anodal]                False         1.9
# (dend, 0, 0)   [cathodal, control, anodal]                False         1.9
# (dend, 0, 1)   [cathodal, control, anodal]                False         1.9
# (dend, 0, 2)   [cathodal, control, anodal]                False         1.9
# (dend, 1, 0)   [cathodal, control, anodal]                False         1.9
# (dend, 1, 1)   [cathodal, control, anodal]                False         1.9
# (dend, 1, 2)   [cathodal, control, anodal]                False         1.9
#
#               mechanism_v                                             data_v
# location
# (soma, 0, 0)            v  [-71.4, -71.39394326795998, -71.38795645729863...
# (apic, 0, 0)            v  [-71.4, -71.3941887534498, -71.38873738189942,...
# (apic, 0, 1)            v  [-71.4, -71.39959623622062, -71.3988365407152,...
# (apic, 0, 2)            v  [-71.4, -71.40025068435602, -71.40044374007513...
# (apic, 0, 3)            v  [-71.4, -71.40056533368208, -71.40111492411098...
# (apic, 0, 4)            v  [-71.4, -71.40077541470346, -71.40153652297698...
# (apic, 0, 5)            v  [-71.4, -71.40085815293298, -71.40171105149791...
# (apic, 0, 6)            v  [-71.4, -71.40093788244546, -71.40186202357795...
# (apic, 0, 7)            v  [-71.4, -71.40093155673158, -71.4018220153362,...
# (apic, 0, 8)            v  [-71.4, -71.40076423193295, -71.40122895234317...
# (apic, 0, 9)            v  [-71.4, -71.39868124317069, -71.39561130591383...
# (apic, 0, 10)           v  [-71.4, -71.37283916224442, -71.34781556762788...
# (dend, 0, 0)            v  [-71.4, -71.39362477338582, -71.38722373830744...
# (dend, 0, 1)            v  [-71.4, -71.3945520406483, -71.38701109867108,...
# (dend, 0, 2)            v  [-71.4, -71.37321915728774, -71.34873965807942...
# (dend, 1, 0)            v  [-71.4, -71.39417094235613, -71.38821140158142...
# (dend, 1, 1)            v  [-71.4, -71.39601379084952, -71.38929951142028...
# (dend, 1, 2)            v  [-71.4, -71.37425361900759, -71.35142144058004...
#
# [18 rows x 129 columns]
